# %% [markdown]
# # LASI2022 - Introduction to Machine Learning
#
# ## Multiple Linear Regression

# %% [markdown]
# ## 0. Load Libraries

# %%
import pandas as pd
from statsmodels.formula.api import ols

# %% [markdown]
# ## 1. Load and Verify Data

# %%
df = pd.read_csv("data/academicperformance.csv")
df.head()
# Out:
#    GPA  Income  Sleep  Time  Grade
# 0  2.9   82461    6.5    47     77
# 1  3.7   61113    6.2    47     94
# 2  2.8   63632    6.2    39     69
# 3  2.0   66854    7.2    49     81
# 4  2.8   82721    5.5    49     78

# %% [markdown]
# ## 2. Fit Model

# %%
mlr = ols('Grade ~ GPA + Sleep + Time + Income', df).fit()

# %%
mlr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Grade   R-squared:                       0.891
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     4239.
# Date:                Fri, 17 Jun 2022   Prob (F-statistic):               0.00
# Time:                        10:15:58   Log-Likelihood:                -6191.0
# No. Observations:                2077   AIC:                         1.239e+04
# Df Residuals:                    2072   BIC:                         1.242e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -40.1454      1.017    -39.472      0.000     -42.140     -38.151
# GPA            9.0993      0.136     67.062      0.000       8.833       9.365
# Sleep          7.2066      0.104     69.490      0.000       7.003       7.410
# Time           1.0579      0.011     95.088      0.000       1.036       1.080
# Income      5.843e-06   6.86e-06      0.851      0.395   -7.62e-06    1.93e-05
# ==============================================================================
# Omnibus:                        1.203   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.548   Jarque-Bera (JB):                1.135
# Skew:                          -0.016   Prob(JB):                        0.567
# Kurtosis:                       3.110   Cond. No.                     7.49e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
mlr = ols('Grade ~ GPA + Sleep + Time', df).fit()

# %% [markdown]
# ## 3. Make Predictions

# %%
data = {'GPA':[3,3,3,2,3,4,2.5,2.5,2.5],
        'Sleep':[5,6,7,6,6,6,5,5,5],
        'Time':[30,30,30,30,30,30,40,50,60]}
df_predict = pd.DataFrame(data)

# %%
df_predict['Grade'] = mlr.predict(df_predict).round(1)

# %%
df_predict
# Out:
#    GPA  Sleep  Time  Grade
# 0  3.0      5    30   55.4
# 1  3.0      6    30   62.6
# 2  3.0      7    30   69.8
# 3  2.0      6    30   53.5
# 4  3.0      6    30   62.6
# 5  4.0      6    30   71.7
# 6  2.5      5    40   61.4
# 7  2.5      5    50   72.0
# 8  2.5      5    60   82.6

# %% [markdown]
# ## 4. Interpret Model
