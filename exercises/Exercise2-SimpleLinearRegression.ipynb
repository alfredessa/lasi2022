# %% [markdown]
# # LASI2022 Machine Learning Workshop
#
# ## Exercise 2: Simple Linear Regression
#
# In this exercise we are interested in studying the relation between campaign expenditures (``shareA`` = share of campaign spending in %) and election outcomes (``voteA`` = share of vote in %).. Our regression model is:
#
# $$ voteA = \beta_0 + \beta_1 \times shareA + \epsilon$$
#
# Our goal is to estimate the parameters: $\beta_0, \beta_1$

# %% [markdown]
# ## 0. Import Python Libraries

# %% [markdown]
# ## 1. Import and Verify Dataset

# %% [markdown]
# ## 2. Plot Distributions of voteA, shareA

# %% [markdown]
# ## 3. Fit Simple Linear Regression Model

# %% [markdown]
# ## 5. Interpret Model
#
# One additional percent of campaign expenditures is associated with an increase/decrease of what percentage of vote?

# %%
One additional

# %% [markdown]
# ## 6. Evaluate Model
